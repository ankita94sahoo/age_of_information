# %% [markdown]
# <a href="https://colab.research.google.com/github/ankita94sahoo/age_of_information/blob/master/Bitcoin_Prediction_analysis_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bitcoin Time Series Forecasting
# Bitcoin is the longest running and most well known cryptocurrency, first released as open source in 2009 by the anonymous Satoshi Nakamoto. Bitcoin serves as a decentralized medium of digital exchange, with transactions verified and recorded in a public distributed ledger (the blockchain) without the need for a trusted record keeping authority or central intermediary. Transaction blocks contain a SHA-256 cryptographic hash of previous transaction blocks, and are thus "chained" together, serving as an immutable record of all transactions that have ever occurred. As with any currency/commodity on the market, bitcoin trading and financial instruments soon followed public adoption of bitcoin and continue to grow. If you don't know what Bitcoin is , then get some knowledge about Bitcoin here .

# %%
# pip install plotly

# %%
import numpy as np #linear algebra
import pandas as pd #data processing, CSV files I/O
import matplotlib.pyplot as plt

from plotly import tools
import plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import gc

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
bitcoin = pd.read_csv('/content/drive/MyDrive/Semester Project/coinbaseUSD_1-min_data_2014-12-01_to_2018-11-11.csv.zip',
                   index_col=[0], parse_dates=[0]) # We set the index column and know it has dates

# %%
bitcoin.head(5)
# Out:
#              Open   High  ...  Volume_(Currency)  Weighted_Price
# Timestamp                 ...
# 1417411980  300.0  300.0  ...                3.0           300.0
# 1417412040    NaN    NaN  ...                NaN             NaN
# 1417412100    NaN    NaN  ...                NaN             NaN
# 1417412160    NaN    NaN  ...                NaN             NaN
# 1417412220    NaN    NaN  ...                NaN             NaN
#
# [5 rows x 7 columns]

# %% [markdown]
# **Data Exploration**
#
# In this section we just explore the Data i.e the Historic Bitcoin Prices and try to find some insights. We will be using the Coinbase dataset as it is one of the mostly used Bitcoin Exchange/Wallet in the world.

# %%
import datetime, pytz
#define a conversion function for the native timestamps in the csv file
def dateparse (time_in_secs):    
    return pytz.utc.localize(datetime.datetime.fromtimestamp(float(time_in_secs)))


data = pd.read_csv('/content/drive/MyDrive/Semester Project/coinbaseUSD_1-min_data_2014-12-01_to_2018-11-11.csv.zip',
                   index_col=[0], parse_dates=[0])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2016354 entries, 1417411980 to 1541894400
# Data columns (total 7 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Open               float64
#  1   High               float64
#  2   Low                float64
#  3   Close              float64
#  4   Volume_(BTC)       float64
#  5   Volume_(Currency)  float64
#  6   Weighted_Price     float64
# dtypes: float64(7)
# memory usage: 123.1 MB

# %% [markdown]
# Little preprocessing required, replacing the NaN values with zeroes and previous data.

# %%
# First thing is to fix the data for bars/candles where there are no trades. 
# Volume/trades are a single event so fill na's with zeroes for relevant fields...
data['Volume_(BTC)'].fillna(value=0, inplace=True)
data['Volume_(Currency)'].fillna(value=0, inplace=True)
data['Weighted_Price'].fillna(value=0, inplace=True)

# next we need to fix the OHLC (open high low close) data which is a continuous timeseries so
# lets fill forwards those values...
data['Open'].fillna(method='ffill', inplace=True)
data['High'].fillna(method='ffill', inplace=True)
data['Low'].fillna(method='ffill', inplace=True)
data['Close'].fillna(method='ffill', inplace=True)

data.head()
# Out:
#              Open   High  ...  Volume_(Currency)  Weighted_Price
# Timestamp                 ...
# 1417411980  300.0  300.0  ...                3.0           300.0
# 1417412040  300.0  300.0  ...                0.0             0.0
# 1417412100  300.0  300.0  ...                0.0             0.0
# 1417412160  300.0  300.0  ...                0.0             0.0
# 1417412220  300.0  300.0  ...                0.0             0.0
#
# [5 rows x 7 columns]

# %% [markdown]
# Creating Weekly Rows for the Data Visualization

# %%
# create valid date range
start = datetime.datetime(2015, 1, 1, 0, 0, 0, 0, pytz.UTC)
end = datetime.datetime(2018, 11, 11, 0, 0, 0, 0, pytz.UTC)

# %%
data.head()
# Out:
#              Open   High  ...  Volume_(Currency)  Weighted_Price
# Timestamp                 ...
# 1417411980  300.0  300.0  ...                3.0           300.0
# 1417412040  300.0  300.0  ...                0.0             0.0
# 1417412100  300.0  300.0  ...                0.0             0.0
# 1417412160  300.0  300.0  ...                0.0             0.0
# 1417412220  300.0  300.0  ...                0.0             0.0
#
# [5 rows x 7 columns]

# %%
# data['Timestamp']=data.index
data= data.reset_index()

# %%
data.head(5)
# Out:
#     Timestamp   Open   High  ...  Volume_(BTC)  Volume_(Currency)  Weighted_Price
# 0  1417411980  300.0  300.0  ...          0.01                3.0           300.0
# 1  1417412040  300.0  300.0  ...          0.00                0.0             0.0
# 2  1417412100  300.0  300.0  ...          0.00                0.0             0.0
# 3  1417412160  300.0  300.0  ...          0.00                0.0             0.0
# 4  1417412220  300.0  300.0  ...          0.00                0.0             0.0
#
# [5 rows x 8 columns]

# %%
data['Timestamp'] = data['Timestamp'].apply(dateparse)
# data['Timestamp'] = dateparse(data['Timestamp'])

# %%
# find rows between start and end time and find the first row (00:00 monday morning)
weekly_rows = data[(data['Timestamp'] >= start) & (data['Timestamp'] <= end)].groupby([pd.Grouper(key='Timestamp', freq='W-MON')]).first().reset_index()
# weekly_rows= weekly_rows.drop(['Timestamp_final'],axis=1)
weekly_rows.head()
# Out:
#                   Timestamp    Open  ...  Volume_(Currency)  Weighted_Price
# 0 2015-01-12 00:00:00+00:00  360.00  ...           3.600000          360.00
# 1 2015-01-19 00:00:00+00:00  260.00  ...         260.000000          260.00
# 2 2015-01-26 00:00:00+00:00  225.51  ...           0.000000            0.00
# 3 2015-02-02 00:00:00+00:00  274.73  ...          66.704444          274.73
# 4 2015-02-09 00:00:00+00:00  237.83  ...           0.000000            0.00
#
# [5 rows x 8 columns]

# %%
#Historical Bitcoin Prices (2015-2018)
fig,(ax1) = plt.subplots(1,sharex=True, figsize=(10,10))
x = weekly_rows['Timestamp']
y = weekly_rows['Open']

x1 = weekly_rows['Timestamp']
y1 = weekly_rows['Close']

x2 = weekly_rows['Timestamp']
y2 = weekly_rows['Weighted_Price']

ax1.plot(x,y)
ax1.plot(x1,y1)
ax1.plot(x2,y2)

# %% [markdown]
# Lets visualize Historical Bitcoin Market Volume (2015-2018)

# %%
# #Historical Bitcoin Market Volume (2015-2018)
# fig,(ax2) = plt.subplots(1,sharex=True, figsize=(10,10))
# x = weekly_rows['Timestamp'],
# y = weekly_rows['Volume_(Currency)']

# ax2.plot(x,y)

# %%
# trace1 = go.Scatter(
#     x = weekly_rows['Timestamp'],
#     y = weekly_rows['Volume_(Currency)'].astype(float),
#     mode = 'lines',
#     name = 'Bitcoin Price (Open)'
# )

# layout = dict(
#     title='Historical Bitcoin Volume (USD) (2015-2018) with the slider',
#     xaxis=dict(
#         rangeselector=dict(
#             buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=6,
#                      label='6m',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=12,
#                      label='1y',
#                      step='month',
#                      stepmode='backward'),
#                 dict(count=36,
#                      label='3y',
#                      step='month',
#                      stepmode='backward'),
#                 dict(step='all')
#             ])
#         ),
#         rangeslider=dict(
#             visible = True
#         ),
#         type='date'
#     )
# )

# data = [trace1]
# fig = dict(data=data, layout=layout)
# iplot(fig, filename = "Time Series with Rangeslider")

# %% [markdown]
# History of Bitcoin Prices
#
# 1. 18 August 2008, the domain name bitcoin.org was registered.
# 2. November 6th 2010, Bitcoin share capital reaches 1 million USD. Its exchange rate on MtGox reaches USD 0.50 per BTC.
# 3. June 2nd 2011, USD to BTC rate is 10 USD to the coin. For 6 days, the Bitcoin value is fixed at 31.91 USD on MtGox.
# 4. February 28th 2013, Bitcoin exchange rate surpasses 31.91 USD for the first time for the last 601 days.
# 5. April 1st,2013 Exchange rate of Bitcoin reaches 100 USD to 1 BTC.
# January,2015 Coinbase raised 75 million USD as part of a Series C funding round, smashing the previous record for a bitcoin company.
# 6. February ,2015 Bitcoin price reached USD 262.
# 7. January 2017,After the rally for most of the second half of 2016, bitcoin broke the USD 1,000 mark for the first time in 3 years.
# 8. June 12th 2017, Bitcoin exchange rate exceeds USD 3000 to the BTC.
# 9. November 29th 2017, Bitcoin price exceeds USD 10,000.
# 10. December 18th 2017, Bitcoin reaches a record high, but does not reach USD 20,000.
# 11. December 28th 2017, The price of bitcoins fell after South Korea announced additional measures to regulate bitcoin trading, including the potential closure of exchanges, among the volatile movements in the world's third largest cryptocurrency market.
# 12. October 31st 2018, USD 6,300, on the 10 year anniversary of Bitcoin, price holds steady above USD 6,000 during a period of historically low volatility.

# %% [markdown]
# **Time Series Forecasting**
#
# Here in this kernel, we attempt to perform Time Series Analysis on the Historic Bitcoin Price data. We can easily see from the Data Exploration section, that the Bitcoin prices were quite volatile and inconsistent over the years. Its very hard to perform Time series analysis on such volatile data. But here we try to explore the different Time series forecasting models. All the models used in this Kernel are very basic, there is scope of more complex and better performing models.
#
# 1. Time Series forecasting with LSTM
# 2. Time Series forecasting with XGBoost
# 3. Time Series forecasting with Facebook Prophet
# 4. Time Series forecasting with ARIMA

# %% [markdown]
# **Predicting using LSTM**
#
# In the first section, we use LSTM (Long short-term memory ). LSTM units are units of a recurrent neural network (RNN). An RNN composed of LSTM units is often called an LSTM network (or just LSTM). A common LSTM unit is composed of a cell, an input gate, an output gate and a forget gate. The cell remembers values over arbitrary time intervals and the three gates regulate the flow of information into and out of the cell. Read more about LSTMs here.
#
# Though LSTM is not ideal for forecasting turbulent market like Bitcoin but we still take a chance here.

# %%
#load the dataset 
data_lstm = pd.read_csv('/content/drive/MyDrive/Semester Project/coinbaseUSD_1-min_data_2014-12-01_to_2018-11-11.csv.zip',
                   index_col=[0], parse_dates=[0])
# First thing is to fix the data for bars/candles where there are no trades. 
# Volume/trades are a single event so fill na's with zeroes for relevant fields...
data_lstm['Volume_(BTC)'].fillna(value=0, inplace=True)
data_lstm['Volume_(Currency)'].fillna(value=0, inplace=True)
data_lstm['Weighted_Price'].fillna(value=0, inplace=True)

# next we need to fix the OHLC (open high low close) data which is a continuous timeseries so
# lets fill forwards those values...
data_lstm['Open'].fillna(method='ffill', inplace=True)
data_lstm['High'].fillna(method='ffill', inplace=True)
data_lstm['Low'].fillna(method='ffill', inplace=True)
data_lstm['Close'].fillna(method='ffill', inplace=True)

data_lstm.head()
# Out:
#              Open   High  ...  Volume_(Currency)  Weighted_Price
# Timestamp                 ...
# 1417411980  300.0  300.0  ...                3.0           300.0
# 1417412040  300.0  300.0  ...                0.0             0.0
# 1417412100  300.0  300.0  ...                0.0             0.0
# 1417412160  300.0  300.0  ...                0.0             0.0
# 1417412220  300.0  300.0  ...                0.0             0.0
#
# [5 rows x 7 columns]

# %%
data_lstm= data_lstm.reset_index()

# %%
data_lstm['Timestamp'] = data_lstm['Timestamp'].apply(dateparse)
data_lstm.head()
# Out:
#                   Timestamp   Open  ...  Volume_(Currency)  Weighted_Price
# 0 2014-12-01 05:33:00+00:00  300.0  ...                3.0           300.0
# 1 2014-12-01 05:34:00+00:00  300.0  ...                0.0             0.0
# 2 2014-12-01 05:35:00+00:00  300.0  ...                0.0             0.0
# 3 2014-12-01 05:36:00+00:00  300.0  ...                0.0             0.0
# 4 2014-12-01 05:37:00+00:00  300.0  ...                0.0             0.0
#
# [5 rows x 8 columns]

# %%
data_lstm.index
# Out:
# RangeIndex(start=0, stop=2016354, step=1)

# %%
data_lstm['Timestamp'] = data_lstm['Timestamp'].dt.tz_localize(None)
data_lstm = data_lstm.groupby([pd.Grouper(key='Timestamp', freq='H')]).first().reset_index()
data_lstm = data_lstm.set_index('Timestamp')
data_lstm = data_lstm[['Weighted_Price']]
data_lstm['Weighted_Price'].fillna(method='ffill', inplace=True)

# %%
# split data
split_date = '25-06-2018'
# from datetime import datetime
# split_date_obj = datetime. strptime(split_date, "%d-%m-%Y %H:%M:%S")
data_train = data_lstm.loc[data_lstm.index <= split_date].copy()
data_test = data_lstm.loc[data_lstm.index > split_date].copy()

# %%
#Checking the length of dataset
print('DataSet length =',len(data_lstm))
print('Train dataset length =',len(data_train))
print('Test dataset length =',len(data_test))
# Out:
# DataSet length = 34580
# Train dataset length = 31244
# Test dataset length = 3336

# %%
data_train.head()
# Out:
#                      Weighted_Price
# Timestamp
# 2014-12-01 05:00:00           300.0
# 2014-12-01 06:00:00             0.0
# 2014-12-01 07:00:00             0.0
# 2014-12-01 08:00:00             0.0
# 2014-12-01 09:00:00             0.0

# %%
# Data preprocess
training_set = data_train.values
training_set = np.reshape(training_set, (len(training_set), 1))
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
training_set = sc.fit_transform(training_set)
X_train = training_set[0:len(training_set)-1]
y_train = training_set[1:len(training_set)]
X_train = np.reshape(X_train, (len(X_train), 1, 1))

# %%
data_lstm.dtypes
# Out:
# Weighted_Price    float64
# dtype: object

# %%
color_pal = ["#F8766D", "#D39200", "#93AA00", "#00BA38", "#00C19F", "#00B9E3", "#619CFF", "#DB72FB"]
_ = data_lstm.plot(style='', figsize=(15,5), color=color_pal[0], title='BTC Weighted_Price Price (USD) by Hours')

# %%
_ = data_test\
    .rename(columns={'Weighted_Price': 'Test Set'}) \
    .join(data_train.rename(columns={'Weighted_Price': 'Training Set'}), how='outer') \
    .plot(figsize=(15,5), title='BTC Weighted_Price Price (USD) by Hours', style='')

# %% [markdown]
# Vanilla LSTM here for forecasting. The model is trained on pre 25-Jun-2018 data.

# %%
# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Activation


model = Sequential()
model.add(LSTM(128,activation="sigmoid",input_shape=(1,1)))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=100, batch_size=50, verbose=2)
# Out:
# Epoch 1/100
# 625/625 - 4s - loss: 0.0381 - 4s/epoch - 6ms/step
# Epoch 2/100
# 625/625 - 2s - loss: 0.0124 - 2s/epoch - 4ms/step
# Epoch 3/100
# 625/625 - 2s - loss: 0.0068 - 2s/epoch - 4ms/step
# Epoch 4/100
# 625/625 - 2s - loss: 0.0047 - 2s/epoch - 4ms/step
# Epoch 5/100
# 625/625 - 2s - loss: 0.0036 - 2s/epoch - 3ms/step
# Epoch 6/100
# 625/625 - 2s - loss: 0.0029 - 2s/epoch - 3ms/step
# Epoch 7/100
# 625/625 - 2s - loss: 0.0025 - 2s/epoch - 3ms/step
# Epoch 8/100
# 625/625 - 2s - loss: 0.0022 - 2s/epoch - 4ms/step
# Epoch 9/100
# 625/625 - 2s - loss: 0.0019 - 2s/epoch - 3ms/step
# Epoch 10/100
# 625/625 - 2s - loss: 0.0017 - 2s/epoch - 4ms/step
# Epoch 11/100
# 625/625 - 2s - loss: 0.0016 - 2s/epoch - 3ms/step
# Epoch 12/100
# 625/625 - 2s - loss: 0.0014 - 2s/epoch - 3ms/step
# Epoch 13/100
# 625/625 - 2s - loss: 0.0013 - 2s/epoch - 3ms/step
# Epoch 14/100
# 625/625 - 2s - loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 15/100
# 625/625 - 2s - loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 16/100
# 625/625 - 2s - loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 17/100
# 625/625 - 2s - loss: 0.0010 - 2s/epoch - 4ms/step
# Epoch 18/100
# 625/625 - 2s - loss: 9.7810e-04 - 2s/epoch - 4ms/step
# Epoch 19/100
# 625/625 - 2s - loss: 9.2382e-04 - 2s/epoch - 4ms/step
# Epoch 20/100
# 625/625 - 2s - loss: 8.8261e-04 - 2s/epoch - 3ms/step
# Epoch 21/100
# 625/625 - 2s - loss: 8.5727e-04 - 2s/epoch - 4ms/step
# Epoch 22/100
# 625/625 - 2s - loss: 8.2811e-04 - 2s/epoch - 3ms/step
# Epoch 23/100
# 625/625 - 2s - loss: 8.0699e-04 - 2s/epoch - 3ms/step
# Epoch 24/100
# 625/625 - 2s - loss: 7.5672e-04 - 2s/epoch - 3ms/step
# Epoch 25/100
# 625/625 - 2s - loss: 7.6871e-04 - 2s/epoch - 3ms/step
# Epoch 26/100
# 625/625 - 2s - loss: 7.4658e-04 - 2s/epoch - 3ms/step
# Epoch 27/100
# 625/625 - 2s - loss: 7.3205e-04 - 2s/epoch - 3ms/step
# Epoch 28/100
# 625/625 - 2s - loss: 7.0877e-04 - 2s/epoch - 3ms/step
# Epoch 29/100
# 625/625 - 2s - loss: 7.0141e-04 - 2s/epoch - 3ms/step
# Epoch 30/100
# 625/625 - 2s - loss: 6.9015e-04 - 2s/epoch - 3ms/step
# Epoch 31/100
# 625/625 - 2s - loss: 6.5698e-04 - 2s/epoch - 3ms/step
# Epoch 32/100
# 625/625 - 2s - loss: 6.6136e-04 - 2s/epoch - 3ms/step
# Epoch 33/100
# 625/625 - 2s - loss: 6.7105e-04 - 2s/epoch - 3ms/step
# Epoch 34/100
# 625/625 - 2s - loss: 6.6013e-04 - 2s/epoch - 4ms/step
# Epoch 35/100
# 625/625 - 2s - loss: 6.3468e-04 - 2s/epoch - 3ms/step
# Epoch 36/100
# 625/625 - 2s - loss: 6.3766e-04 - 2s/epoch - 3ms/step
# Epoch 37/100
# 625/625 - 2s - loss: 6.3774e-04 - 2s/epoch - 3ms/step
# Epoch 38/100
# 625/625 - 2s - loss: 6.3405e-04 - 2s/epoch - 3ms/step
# Epoch 39/100
# 625/625 - 2s - loss: 6.4288e-04 - 2s/epoch - 3ms/step
# Epoch 40/100
# 625/625 - 2s - loss: 6.1895e-04 - 2s/epoch - 3ms/step
# Epoch 41/100
# 625/625 - 2s - loss: 6.2280e-04 - 2s/epoch - 4ms/step
# Epoch 42/100
# 625/625 - 2s - loss: 6.0890e-04 - 2s/epoch - 4ms/step
# Epoch 43/100
# 625/625 - 2s - loss: 6.1932e-04 - 2s/epoch - 4ms/step
# Epoch 44/100
# 625/625 - 2s - loss: 5.9250e-04 - 2s/epoch - 3ms/step
# Epoch 45/100
# 625/625 - 2s - loss: 6.1432e-04 - 2s/epoch - 3ms/step
# Epoch 46/100
# 625/625 - 2s - loss: 5.8915e-04 - 2s/epoch - 3ms/step
# Epoch 47/100
# 625/625 - 2s - loss: 6.1410e-04 - 2s/epoch - 4ms/step
# Epoch 48/100
# 625/625 - 2s - loss: 6.0533e-04 - 2s/epoch - 4ms/step
# Epoch 49/100
# 625/625 - 2s - loss: 5.9354e-04 - 2s/epoch - 4ms/step
# Epoch 50/100
# 625/625 - 2s - loss: 5.8723e-04 - 2s/epoch - 3ms/step
# Epoch 51/100
# 625/625 - 2s - loss: 5.9182e-04 - 2s/epoch - 3ms/step
# Epoch 52/100
# 625/625 - 2s - loss: 5.9316e-04 - 2s/epoch - 4ms/step
# Epoch 53/100
# 625/625 - 2s - loss: 5.9625e-04 - 2s/epoch - 4ms/step
# Epoch 54/100
# 625/625 - 2s - loss: 5.8414e-04 - 2s/epoch - 3ms/step
# Epoch 55/100
# 625/625 - 2s - loss: 6.0534e-04 - 2s/epoch - 3ms/step
# Epoch 56/100
# 625/625 - 2s - loss: 5.7851e-04 - 2s/epoch - 3ms/step
# Epoch 57/100
# 625/625 - 2s - loss: 5.7683e-04 - 2s/epoch - 4ms/step
# Epoch 58/100
# 625/625 - 2s - loss: 5.8494e-04 - 2s/epoch - 3ms/step
# Epoch 59/100
# 625/625 - 2s - loss: 5.7874e-04 - 2s/epoch - 3ms/step
# Epoch 60/100
# 625/625 - 2s - loss: 5.6594e-04 - 2s/epoch - 3ms/step
# Epoch 61/100
# 625/625 - 2s - loss: 5.8547e-04 - 2s/epoch - 3ms/step
# Epoch 62/100
# 625/625 - 2s - loss: 5.8002e-04 - 2s/epoch - 3ms/step
# Epoch 63/100
# 625/625 - 2s - loss: 5.8345e-04 - 2s/epoch - 3ms/step
# Epoch 64/100
# 625/625 - 2s - loss: 5.8459e-04 - 2s/epoch - 3ms/step
# Epoch 65/100
# 625/625 - 2s - loss: 5.7638e-04 - 2s/epoch - 4ms/step
# Epoch 66/100
# 625/625 - 2s - loss: 5.8570e-04 - 2s/epoch - 3ms/step
# Epoch 67/100
# 625/625 - 2s - loss: 5.8191e-04 - 2s/epoch - 4ms/step
# Epoch 68/100
# 625/625 - 2s - loss: 5.6808e-04 - 2s/epoch - 3ms/step
# Epoch 69/100
# 625/625 - 2s - loss: 5.7618e-04 - 2s/epoch - 4ms/step
# Epoch 70/100
# 625/625 - 2s - loss: 5.8244e-04 - 2s/epoch - 4ms/step
# Epoch 71/100
# 625/625 - 2s - loss: 5.6563e-04 - 2s/epoch - 4ms/step
# Epoch 72/100
# 625/625 - 2s - loss: 5.7328e-04 - 2s/epoch - 3ms/step
# Epoch 73/100
# 625/625 - 2s - loss: 5.9180e-04 - 2s/epoch - 3ms/step
# Epoch 74/100
# 625/625 - 2s - loss: 5.7121e-04 - 2s/epoch - 3ms/step
# Epoch 75/100
# 625/625 - 2s - loss: 5.8199e-04 - 2s/epoch - 4ms/step
# Epoch 76/100
# 625/625 - 2s - loss: 5.7321e-04 - 2s/epoch - 3ms/step
# Epoch 77/100
# 625/625 - 2s - loss: 5.5524e-04 - 2s/epoch - 3ms/step
# Epoch 78/100
# 625/625 - 2s - loss: 5.6955e-04 - 2s/epoch - 3ms/step
# Epoch 79/100
# 625/625 - 2s - loss: 5.7396e-04 - 2s/epoch - 3ms/step
# Epoch 80/100
# 625/625 - 2s - loss: 5.6783e-04 - 2s/epoch - 3ms/step
# Epoch 81/100
# 625/625 - 2s - loss: 5.6660e-04 - 2s/epoch - 3ms/step
# Epoch 82/100
# 625/625 - 2s - loss: 5.6376e-04 - 2s/epoch - 3ms/step
# Epoch 83/100
# 625/625 - 2s - loss: 5.6759e-04 - 2s/epoch - 3ms/step
# Epoch 84/100
# 625/625 - 2s - loss: 5.5421e-04 - 2s/epoch - 3ms/step
# Epoch 85/100
# 625/625 - 2s - loss: 5.7523e-04 - 2s/epoch - 4ms/step
# Epoch 86/100
# 625/625 - 2s - loss: 5.7234e-04 - 2s/epoch - 4ms/step
# Epoch 87/100
# 625/625 - 2s - loss: 5.6924e-04 - 2s/epoch - 4ms/step
# Epoch 88/100
# 625/625 - 2s - loss: 5.6457e-04 - 2s/epoch - 3ms/step
# Epoch 89/100
# 625/625 - 2s - loss: 5.6798e-04 - 2s/epoch - 3ms/step
# Epoch 90/100
# 625/625 - 2s - loss: 5.6487e-04 - 2s/epoch - 4ms/step
# Epoch 91/100
# 625/625 - 2s - loss: 5.5599e-04 - 2s/epoch - 4ms/step
# Epoch 92/100
# 625/625 - 2s - loss: 5.6850e-04 - 2s/epoch - 4ms/step
# Epoch 93/100
# 625/625 - 2s - loss: 5.5957e-04 - 2s/epoch - 4ms/step
# Epoch 94/100
# 625/625 - 2s - loss: 5.6762e-04 - 2s/epoch - 3ms/step
# Epoch 95/100
# 625/625 - 2s - loss: 5.4818e-04 - 2s/epoch - 4ms/step
# Epoch 96/100
# 625/625 - 2s - loss: 5.5895e-04 - 2s/epoch - 4ms/step
# Epoch 97/100
# 625/625 - 2s - loss: 5.6186e-04 - 2s/epoch - 4ms/step
# Epoch 98/100
# 625/625 - 2s - loss: 5.5048e-04 - 2s/epoch - 4ms/step
# Epoch 99/100
# 625/625 - 2s - loss: 5.6732e-04 - 2s/epoch - 3ms/step
# Epoch 100/100
# 625/625 - 2s - loss: 5.6445e-04 - 2s/epoch - 3ms/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               66560
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Making the predictions
test_set = data_test.values
inputs = np.reshape(test_set, (len(test_set), 1))
inputs = sc.transform(inputs)
inputs = np.reshape(inputs, (len(inputs), 1, 1))
predicted_BTC_price = model.predict(inputs)
predicted_BTC_price = sc.inverse_transform(predicted_BTC_price)

# %%
data_test['Weighted_Price_Prediction'] = predicted_BTC_price
data_all = pd.concat([data_test, data_train], sort=False)

# %%
#saving the predicted values in a common data frame for future comparision
final_data = data_all
final_data = final_data.reset_index()
final_data = final_data.rename(columns={'Weighted_Price_Prediction': 'lstm'})
final_data = final_data[['Timestamp','Weighted_Price','lstm']]

# %%
final_data.head()
# Out:
#             Timestamp  Weighted_Price         lstm
# 0 2018-06-25 01:00:00     6167.635238  5955.389160
# 1 2018-06-25 02:00:00     6144.630000  5933.306641
# 2 2018-06-25 03:00:00     6134.470000  5923.560059
# 3 2018-06-25 04:00:00     6148.723959  5937.235840
# 4 2018-06-25 05:00:00     6139.230900  5928.126953

# %%
_ = data_all[['Weighted_Price','Weighted_Price_Prediction']].plot(figsize=(15, 5))

# %%
#calculate MSE and MAE
from sklearn.metrics import mean_squared_error, mean_absolute_error
mean_squared_error(y_true=data_test['Weighted_Price'],
                   y_pred=data_test['Weighted_Price_Prediction'])
# Out:
# 49465.69865469701

# %%
mean_absolute_error(y_true=data_test['Weighted_Price'],
                   y_pred=data_test['Weighted_Price_Prediction'])
# Out:
# 222.03830080580477

# %% [markdown]
# Putting Static Delay to dataset

# %%
data_lstm.index
# Out:
# DatetimeIndex(['2014-12-01 05:00:00', '2014-12-01 06:00:00',
#                '2014-12-01 07:00:00', '2014-12-01 08:00:00',
#                '2014-12-01 09:00:00', '2014-12-01 10:00:00',
#                '2014-12-01 11:00:00', '2014-12-01 12:00:00',
#                '2014-12-01 13:00:00', '2014-12-01 14:00:00',
#                ...
#                '2018-11-10 15:00:00', '2018-11-10 16:00:00',
#                '2018-11-10 17:00:00', '2018-11-10 18:00:00',
#                '2018-11-10 19:00:00', '2018-11-10 20:00:00',
#                '2018-11-10 21:00:00', '2018-11-10 22:00:00',
#                '2018-11-10 23:00:00', '2018-11-11 00:00:00'],
#               dtype='datetime64[ns]', name='Timestamp', length=34580, freq=None)

# %%
data_lstm['Delayed_Time']= data_lstm.index.copy()

# %%
data_lstm.head()
# Out:
#                      Weighted_Price        Delayed_Time
# Timestamp
# 2014-12-01 05:00:00           300.0 2014-12-01 05:00:00
# 2014-12-01 06:00:00             0.0 2014-12-01 06:00:00
# 2014-12-01 07:00:00             0.0 2014-12-01 07:00:00
# 2014-12-01 08:00:00             0.0 2014-12-01 08:00:00
# 2014-12-01 09:00:00             0.0 2014-12-01 09:00:00

# %%
data_lstm.columns
# Out:
# Index(['Weighted_Price', 'Delayed_Time'], dtype='object')

# %%
# data_lstm['Delayed_Time'][1] = data_lstm['Delayed_Time'][1] + dt.rin

rand_int = np.random.randint(1,10,size=34580) #random delay 
# static_int = 30 #to calculate static delay
# rand_int = np.random.uniform(1,10,size=34580) #uniform delay
data_lstm['rand_int'] = rand_int
#pjme['static_int'] = static_int
data_lstm.head(5)
# Out:
#                      Weighted_Price        Delayed_Time  rand_int
# Timestamp
# 2014-12-01 05:00:00           300.0 2014-12-01 05:00:00         6
# 2014-12-01 06:00:00             0.0 2014-12-01 06:00:00         4
# 2014-12-01 07:00:00             0.0 2014-12-01 07:00:00         3
# 2014-12-01 08:00:00             0.0 2014-12-01 08:00:00         9
# 2014-12-01 09:00:00             0.0 2014-12-01 09:00:00         4

# %%
data_lstm['Delayed_Time'] = data_lstm.Delayed_Time + data_lstm.rand_int.astype('timedelta64[h]') #to convert delay to minutes
# data_lstm['Delayed_Time'] = data_lstm.Delayed_Time + data_lstm.rand_int.astype('timedelta64[m]') #to convert delay to minutes
# data_lstm['Delayed_Time'] = data_lstm.Delayed_Time + data_lstm.rand_int.astype('timedelta64[s]') #to convert delay to seconds
data_lstm.head(5)
# Out:
#                      Weighted_Price        Delayed_Time  rand_int
# Timestamp
# 2014-12-01 05:00:00           300.0 2014-12-01 11:00:00         6
# 2014-12-01 06:00:00             0.0 2014-12-01 10:00:00         4
# 2014-12-01 07:00:00             0.0 2014-12-01 10:00:00         3
# 2014-12-01 08:00:00             0.0 2014-12-01 17:00:00         9
# 2014-12-01 09:00:00             0.0 2014-12-01 13:00:00         4

# %%
data_lstm.set_index('Delayed_Time')
# Out:
#                      Weighted_Price  rand_int
# Delayed_Time
# 2014-12-01 11:00:00      300.000000         6
# 2014-12-01 10:00:00        0.000000         4
# 2014-12-01 10:00:00        0.000000         3
# 2014-12-01 17:00:00        0.000000         9
# 2014-12-01 13:00:00        0.000000         4
# ...                             ...       ...
# 2018-11-11 03:00:00     6358.393352         7
# 2018-11-11 01:00:00     6364.992297         4
# 2018-11-11 02:00:00     6361.263244         4
# 2018-11-11 02:00:00     6364.111032         3
# 2018-11-11 03:00:00     6347.417439         3
#
# [34580 rows x 2 columns]

# %%
data_lstm_delayed = data_lstm.set_index('Delayed_Time')

# %%
data_lstm_delayed.head()
# Out:
#                      Weighted_Price  rand_int
# Delayed_Time
# 2014-12-01 11:00:00           300.0         6
# 2014-12-01 10:00:00             0.0         4
# 2014-12-01 10:00:00             0.0         3
# 2014-12-01 17:00:00             0.0         9
# 2014-12-01 13:00:00             0.0         4

# %%
data_lstm_delayed = data_lstm_delayed.drop(['rand_int'],axis=1)

# %%
data_lstm_delayed.head()
# Out:
#                      Weighted_Price
# Delayed_Time
# 2014-12-01 11:00:00           300.0
# 2014-12-01 10:00:00             0.0
# 2014-12-01 10:00:00             0.0
# 2014-12-01 17:00:00             0.0
# 2014-12-01 13:00:00             0.0

# %%
#export to csv file
data_lstm_delayed.to_csv(r'/content/drive/MyDrive/Semester Project/data_lstm_delayed.csv')

# %%
#Splitting the delayed datset
# split data
split_date = '25-06-2018'
# from datetime import datetime
# split_date_obj = datetime. strptime(split_date, "%d-%m-%Y %H:%M:%S")
data_train_delayed = data_lstm_delayed.loc[data_lstm_delayed.index <= split_date].copy()
data_test_delayed = data_lstm_delayed.loc[data_lstm_delayed.index > split_date].copy()

# %%
#Checking the length of dataset
print('DataSet length =',len(data_lstm_delayed))
print('Train dataset length =',len(data_train_delayed))
print('Test dataset length =',len(data_test_delayed))
# Out:
# DataSet length = 34580
# Train dataset length = 31239
# Test dataset length = 3341

# %%
# Data preprocess
training_set_delayed = data_train_delayed.values
training_set_delayed = np.reshape(training_set_delayed, (len(training_set_delayed), 1))
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
training_set_delayed = sc.fit_transform(training_set_delayed)
X_train_delayed = training_set_delayed[0:len(training_set_delayed)-1]
y_train_delayed = training_set_delayed[1:len(training_set_delayed)]
X_train_delayed = np.reshape(X_train_delayed, (len(X_train_delayed), 1, 1))

# %%
# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Activation


model = Sequential()
model.add(LSTM(128,activation="sigmoid",input_shape=(1,1)))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train_delayed, y_train_delayed, epochs=100, batch_size=50, verbose=2)
# Out:
# Epoch 1/100
# 625/625 - 4s - loss: 0.0379 - 4s/epoch - 6ms/step
# Epoch 2/100
# 625/625 - 2s - loss: 0.0127 - 2s/epoch - 4ms/step
# Epoch 3/100
# 625/625 - 2s - loss: 0.0068 - 2s/epoch - 4ms/step
# Epoch 4/100
# 625/625 - 3s - loss: 0.0047 - 3s/epoch - 4ms/step
# Epoch 5/100
# 625/625 - 2s - loss: 0.0037 - 2s/epoch - 3ms/step
# Epoch 6/100
# 625/625 - 2s - loss: 0.0030 - 2s/epoch - 4ms/step
# Epoch 7/100
# 625/625 - 2s - loss: 0.0026 - 2s/epoch - 3ms/step
# Epoch 8/100
# 625/625 - 2s - loss: 0.0022 - 2s/epoch - 3ms/step
# Epoch 9/100
# 625/625 - 2s - loss: 0.0019 - 2s/epoch - 4ms/step
# Epoch 10/100
# 625/625 - 2s - loss: 0.0018 - 2s/epoch - 3ms/step
# Epoch 11/100
# 625/625 - 2s - loss: 0.0016 - 2s/epoch - 3ms/step
# Epoch 12/100
# 625/625 - 2s - loss: 0.0014 - 2s/epoch - 4ms/step
# Epoch 13/100
# 625/625 - 2s - loss: 0.0014 - 2s/epoch - 4ms/step
# Epoch 14/100
# 625/625 - 2s - loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 15/100
# 625/625 - 2s - loss: 0.0011 - 2s/epoch - 3ms/step
# Epoch 16/100
# 625/625 - 2s - loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 17/100
# 625/625 - 2s - loss: 0.0010 - 2s/epoch - 4ms/step
# Epoch 18/100
# 625/625 - 2s - loss: 9.5193e-04 - 2s/epoch - 3ms/step
# Epoch 19/100
# 625/625 - 2s - loss: 9.3285e-04 - 2s/epoch - 4ms/step
# Epoch 20/100
# 625/625 - 2s - loss: 9.1699e-04 - 2s/epoch - 3ms/step
# Epoch 21/100
# 625/625 - 2s - loss: 8.4377e-04 - 2s/epoch - 4ms/step
# Epoch 22/100
# 625/625 - 2s - loss: 8.2948e-04 - 2s/epoch - 4ms/step
# Epoch 23/100
# 625/625 - 2s - loss: 7.8602e-04 - 2s/epoch - 3ms/step
# Epoch 24/100
# 625/625 - 2s - loss: 7.8494e-04 - 2s/epoch - 3ms/step
# Epoch 25/100
# 625/625 - 2s - loss: 7.5723e-04 - 2s/epoch - 3ms/step
# Epoch 26/100
# 625/625 - 2s - loss: 7.4047e-04 - 2s/epoch - 3ms/step
# Epoch 27/100
# 625/625 - 2s - loss: 7.2754e-04 - 2s/epoch - 3ms/step
# Epoch 28/100
# 625/625 - 2s - loss: 7.1599e-04 - 2s/epoch - 3ms/step
# Epoch 29/100
# 625/625 - 2s - loss: 6.9512e-04 - 2s/epoch - 3ms/step
# Epoch 30/100
# 625/625 - 2s - loss: 7.0025e-04 - 2s/epoch - 4ms/step
# Epoch 31/100
# 625/625 - 2s - loss: 6.9205e-04 - 2s/epoch - 4ms/step
# Epoch 32/100
# 625/625 - 2s - loss: 6.5808e-04 - 2s/epoch - 4ms/step
# Epoch 33/100
# 625/625 - 2s - loss: 6.4783e-04 - 2s/epoch - 3ms/step
# Epoch 34/100
# 625/625 - 2s - loss: 6.5364e-04 - 2s/epoch - 4ms/step
# Epoch 35/100
# 625/625 - 2s - loss: 6.4823e-04 - 2s/epoch - 4ms/step
# Epoch 36/100
# 625/625 - 2s - loss: 6.3928e-04 - 2s/epoch - 3ms/step
# Epoch 37/100
# 625/625 - 2s - loss: 6.2516e-04 - 2s/epoch - 3ms/step
# Epoch 38/100
# 625/625 - 2s - loss: 6.2512e-04 - 2s/epoch - 3ms/step
# Epoch 39/100
# 625/625 - 2s - loss: 6.2833e-04 - 2s/epoch - 3ms/step
# Epoch 40/100
# 625/625 - 2s - loss: 6.2554e-04 - 2s/epoch - 3ms/step
# Epoch 41/100
# 625/625 - 2s - loss: 6.1168e-04 - 2s/epoch - 3ms/step
# Epoch 42/100
# 625/625 - 2s - loss: 6.1054e-04 - 2s/epoch - 3ms/step
# Epoch 43/100
# 625/625 - 2s - loss: 5.9926e-04 - 2s/epoch - 3ms/step
# Epoch 44/100
# 625/625 - 2s - loss: 6.1172e-04 - 2s/epoch - 3ms/step
# Epoch 45/100
# 625/625 - 2s - loss: 6.0440e-04 - 2s/epoch - 3ms/step
# Epoch 46/100
# 625/625 - 2s - loss: 6.0832e-04 - 2s/epoch - 3ms/step
# Epoch 47/100
# 625/625 - 2s - loss: 5.9347e-04 - 2s/epoch - 3ms/step
# Epoch 48/100
# 625/625 - 2s - loss: 6.0227e-04 - 2s/epoch - 3ms/step
# Epoch 49/100
# 625/625 - 2s - loss: 6.0116e-04 - 2s/epoch - 3ms/step
# Epoch 50/100
# 625/625 - 2s - loss: 5.9637e-04 - 2s/epoch - 3ms/step
# Epoch 51/100
# 625/625 - 2s - loss: 5.9141e-04 - 2s/epoch - 3ms/step
# Epoch 52/100
# 625/625 - 2s - loss: 5.9828e-04 - 2s/epoch - 3ms/step
# Epoch 53/100
# 625/625 - 2s - loss: 5.8385e-04 - 2s/epoch - 3ms/step
# Epoch 54/100
# 625/625 - 2s - loss: 5.9967e-04 - 2s/epoch - 3ms/step
# Epoch 55/100
# 625/625 - 2s - loss: 5.8498e-04 - 2s/epoch - 3ms/step
# Epoch 56/100
# 625/625 - 2s - loss: 5.9273e-04 - 2s/epoch - 3ms/step
# Epoch 57/100
# 625/625 - 2s - loss: 6.0112e-04 - 2s/epoch - 4ms/step
# Epoch 58/100
# 625/625 - 2s - loss: 6.0085e-04 - 2s/epoch - 4ms/step
# Epoch 59/100
# 625/625 - 2s - loss: 5.6787e-04 - 2s/epoch - 3ms/step
# Epoch 60/100
# 625/625 - 2s - loss: 5.8245e-04 - 2s/epoch - 3ms/step
# Epoch 61/100
# 625/625 - 2s - loss: 5.7641e-04 - 2s/epoch - 3ms/step
# Epoch 62/100
# 625/625 - 2s - loss: 5.7748e-04 - 2s/epoch - 3ms/step
# Epoch 63/100
# 625/625 - 2s - loss: 5.8637e-04 - 2s/epoch - 3ms/step
# Epoch 64/100
# 625/625 - 2s - loss: 5.9160e-04 - 2s/epoch - 3ms/step
# Epoch 65/100
# 625/625 - 2s - loss: 5.8100e-04 - 2s/epoch - 3ms/step
# Epoch 66/100
# 625/625 - 2s - loss: 5.8335e-04 - 2s/epoch - 3ms/step
# Epoch 67/100
# 625/625 - 2s - loss: 5.6896e-04 - 2s/epoch - 4ms/step
# Epoch 68/100
# 625/625 - 2s - loss: 5.7051e-04 - 2s/epoch - 3ms/step
# Epoch 69/100
# 625/625 - 2s - loss: 5.7734e-04 - 2s/epoch - 3ms/step
# Epoch 70/100
# 625/625 - 2s - loss: 5.8225e-04 - 2s/epoch - 4ms/step
# Epoch 71/100
# 625/625 - 2s - loss: 5.8848e-04 - 2s/epoch - 4ms/step
# Epoch 72/100
# 625/625 - 2s - loss: 5.8203e-04 - 2s/epoch - 3ms/step
# Epoch 73/100
# 625/625 - 2s - loss: 5.7556e-04 - 2s/epoch - 3ms/step
# Epoch 74/100
# 625/625 - 2s - loss: 5.9150e-04 - 2s/epoch - 3ms/step
# Epoch 75/100
# 625/625 - 2s - loss: 5.7287e-04 - 2s/epoch - 3ms/step
# Epoch 76/100
# 625/625 - 2s - loss: 5.6434e-04 - 2s/epoch - 3ms/step
# Epoch 77/100
# 625/625 - 2s - loss: 5.6691e-04 - 2s/epoch - 3ms/step
# Epoch 78/100
# 625/625 - 2s - loss: 5.8386e-04 - 2s/epoch - 3ms/step
# Epoch 79/100
# 625/625 - 2s - loss: 5.7145e-04 - 2s/epoch - 3ms/step
# Epoch 80/100
# 625/625 - 2s - loss: 5.7939e-04 - 2s/epoch - 3ms/step
# Epoch 81/100
# 625/625 - 2s - loss: 5.7221e-04 - 2s/epoch - 3ms/step
# Epoch 82/100
# 625/625 - 2s - loss: 5.7083e-04 - 2s/epoch - 3ms/step
# Epoch 83/100
# 625/625 - 2s - loss: 5.6804e-04 - 2s/epoch - 3ms/step
# Epoch 84/100
# 625/625 - 2s - loss: 5.5754e-04 - 2s/epoch - 3ms/step
# Epoch 85/100
# 625/625 - 2s - loss: 5.6689e-04 - 2s/epoch - 3ms/step
# Epoch 86/100
# 625/625 - 2s - loss: 5.8065e-04 - 2s/epoch - 4ms/step
# Epoch 87/100
# 625/625 - 2s - loss: 5.7002e-04 - 2s/epoch - 4ms/step
# Epoch 88/100
# 625/625 - 2s - loss: 5.7986e-04 - 2s/epoch - 3ms/step
# Epoch 89/100
# 625/625 - 2s - loss: 5.7949e-04 - 2s/epoch - 3ms/step
# Epoch 90/100
# 625/625 - 2s - loss: 5.8428e-04 - 2s/epoch - 3ms/step
# Epoch 91/100
# 625/625 - 2s - loss: 5.6749e-04 - 2s/epoch - 3ms/step
# Epoch 92/100
# 625/625 - 2s - loss: 5.7248e-04 - 2s/epoch - 4ms/step
# Epoch 93/100
# 625/625 - 2s - loss: 5.5045e-04 - 2s/epoch - 3ms/step
# Epoch 94/100
# 625/625 - 2s - loss: 5.7047e-04 - 2s/epoch - 3ms/step
# Epoch 95/100
# 625/625 - 2s - loss: 5.7996e-04 - 2s/epoch - 3ms/step
# Epoch 96/100
# 625/625 - 2s - loss: 5.5478e-04 - 2s/epoch - 3ms/step
# Epoch 97/100
# 625/625 - 2s - loss: 5.6477e-04 - 2s/epoch - 3ms/step
# Epoch 98/100
# 625/625 - 2s - loss: 5.5720e-04 - 2s/epoch - 3ms/step
# Epoch 99/100
# 625/625 - 2s - loss: 5.5487e-04 - 2s/epoch - 3ms/step
# Epoch 100/100
# 625/625 - 2s - loss: 5.6490e-04 - 2s/epoch - 3ms/step

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 128)               66560
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Making the predictions
test_set_delayed = data_test_delayed.values
inputs = np.reshape(test_set_delayed, (len(test_set_delayed), 1))
inputs = sc.transform(inputs)
inputs = np.reshape(inputs, (len(inputs), 1, 1))
predicted_BTC_price = model.predict(inputs)
predicted_BTC_price = sc.inverse_transform(predicted_BTC_price)

# %%
data_test_delayed['Weighted_Price_Prediction'] = predicted_BTC_price
data_all_delayed = pd.concat([data_test, data_train], sort=False)

# %%
#saving the predicted values in a common data frame for future comparision
final_data_delayed = data_all_delayed
final_data_delayed = final_data_delayed.reset_index()
final_data_delayed = final_data_delayed.rename(columns={'Weighted_Price_Prediction': 'lstm'})
final_data_delayed = final_data_delayed[['Timestamp','Weighted_Price','lstm']]

# %%
final_data_delayed.head()
# Out:
#             Timestamp  Weighted_Price         lstm
# 0 2018-06-25 01:00:00     6167.635238  5955.389160
# 1 2018-06-25 02:00:00     6144.630000  5933.306641
# 2 2018-06-25 03:00:00     6134.470000  5923.560059
# 3 2018-06-25 04:00:00     6148.723959  5937.235840
# 4 2018-06-25 05:00:00     6139.230900  5928.126953

# %%
#calculate MSE and MAE
from sklearn.metrics import mean_squared_error, mean_absolute_error
mean_squared_error(y_true=data_test_delayed['Weighted_Price'],
                   y_pred=data_test_delayed['Weighted_Price_Prediction'])
# Out:
# 110882.89702946389

# %%
mean_absolute_error(y_true=data_test_delayed['Weighted_Price'],
                   y_pred=data_test_delayed['Weighted_Price_Prediction'])
# Out:
# 331.8670938192536

# %% [markdown]
# ## Time Series forecasting with XGBoost

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from fbprophet import Prophet
from sklearn.metrics import mean_squared_error, mean_absolute_error
plt.style.use('fivethirtyeight')

# %%
data_xg = pd.read_csv('/content/drive/MyDrive/Semester Project/coinbaseUSD_1-min_data_2014-12-01_to_2018-11-11.csv.zip',
                   index_col=[0], parse_dates=[0])

# %%
data_xg= data_xg.reset_index()
data_xg
# Out:
#           Timestamp     Open  ...  Volume_(Currency)  Weighted_Price
# 0        1417411980   300.00  ...           3.000000      300.000000
# 1        1417412040      NaN  ...                NaN             NaN
# 2        1417412100      NaN  ...                NaN             NaN
# 3        1417412160      NaN  ...                NaN             NaN
# 4        1417412220      NaN  ...                NaN             NaN
# ...             ...      ...  ...                ...             ...
# 2016349  1541894160  6347.41  ...        3078.241490     6347.417225
# 2016350  1541894220  6347.41  ...        4892.318043     6347.419294
# 2016351  1541894280  6347.41  ...        7700.341614     6347.418653
# 2016352  1541894340  6347.41  ...       10880.053958     6347.418881
# 2016353  1541894400  6347.42  ...        3105.944897     6347.417439
#
# [2016354 rows x 8 columns]

# %%
data_xg['Timestamp'] = data_xg['Timestamp'].apply(dateparse)
data_xg.head()
# Out:
#                   Timestamp   Open  ...  Volume_(Currency)  Weighted_Price
# 0 2014-12-01 05:33:00+00:00  300.0  ...                3.0           300.0
# 1 2014-12-01 05:34:00+00:00    NaN  ...                NaN             NaN
# 2 2014-12-01 05:35:00+00:00    NaN  ...                NaN             NaN
# 3 2014-12-01 05:36:00+00:00    NaN  ...                NaN             NaN
# 4 2014-12-01 05:37:00+00:00    NaN  ...                NaN             NaN
#
# [5 rows x 8 columns]

# %%
data_xg['Timestamp'] = data_xg['Timestamp'].dt.tz_localize(None)
data_xg = data_xg.groupby([pd.Grouper(key='Timestamp', freq='H')]).first().reset_index()
data_xg = data_xg.set_index('Timestamp')
data_xg = data_xg[['Weighted_Price']]
data_xg['Weighted_Price'].fillna(method='ffill', inplace=True)

# %%
color_pal = ["#F8766D", "#D39200", "#93AA00", "#00BA38", "#00C19F", "#00B9E3", "#619CFF", "#DB72FB"]
_ = data_xg.plot(style='', figsize=(15,5), color=color_pal[0], title='BTC Weighted_Price Price (USD) by Hours')

# %%
split_date = '25-Jun-2018'
data_train_xg = data_xg.loc[data_xg.index <= split_date].copy()
data_test_xg = data_xg.loc[data_xg.index > split_date].copy()

# %%
_ = data_test_xg \
    .rename(columns={'Weighted_Price': 'Test Set'}) \
    .join(data_train_xg.rename(columns={'Weighted_Price': 'Training Set'}), how='outer') \
    .plot(figsize=(15,5), title='BTC Weighted_Price Price (USD) by Hours', style='')

# %%
def create_features(df, label=None):
    """
    Creates time series features from datetime index
    """
    df['date'] = df.index
    df['hour'] = df['date'].dt.hour
    df['dayofweek'] = df['date'].dt.dayofweek
    df['quarter'] = df['date'].dt.quarter
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    df['dayofyear'] = df['date'].dt.dayofyear
    df['dayofmonth'] = df['date'].dt.day
    df['weekofyear'] = df['date'].dt.weekofyear
    
    X = df[['hour','dayofweek','quarter','month','year',
           'dayofyear','dayofmonth','weekofyear']]
    if label:
        y = df[label]
        return X, y
    return X

# %%
X_train, y_train = create_features(data_train_xg, label='Weighted_Price')
X_test, y_test = create_features(data_test_xg, label='Weighted_Price')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning:
#
# Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
import xgboost as xgb
from xgboost import plot_importance, plot_tree
model =  xgb.XGBRegressor(objective ='reg:linear',min_child_weight=10, booster='gbtree', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 1000)
model.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False) # Change verbose to True if you want to see it train
# Out:
# [12:25:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(alpha=10, colsample_bytree=0.3, max_depth=5, min_child_weight=10,
#              n_estimators=1000)

# %%
data_test_xg['Weighted_Price_Prediction'] = model.predict(X_test)
data_all_xg = pd.concat([data_test_xg, data_train_xg], sort=False)

# %%
#adding to final data for comparision
final_data_xg = pd.merge(final_data_xg, data_all_xg, sort=False)
final_data_xg = final_data_xg.rename(columns={'Weighted_Price_Prediction': 'xgboost'})
final_data_xg = final_data_xg[['Timestamp','Weighted_Price','lstm','xgboost']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-5a464250881b> in <module>()
#       1 #adding to final data for comparision
# ----> 2 final_data_xg = pd.merge(final_data_xg, data_all_xg, sort=False)
#       3 final_data_xg = final_data_xg.rename(columns={'Weighted_Price_Prediction': 'xgboost'})
#       4 final_data_xg = final_data_xg[['Timestamp','Weighted_Price','lstm','xgboost']]
#
# NameError: name 'final_data_xg' is not defined

# %%
_ = data_all_xg[['Weighted_Price','Weighted_Price_Prediction']].plot(figsize=(15, 5))

# %%
mean_squared_error(y_true=data_test_xg['Weighted_Price'],
                   y_pred=data_test_xg['Weighted_Price_Prediction'])

# %%
mean_absolute_error(y_true=data_test_xg['Weighted_Price'],
                   y_pred=data_test_xg['Weighted_Price_Prediction'])

# %% [markdown]
# **Analysis for the delayed Dataset**

# %%
data_xg['Delayed_Time']= data_xg.index.copy()

# %%
# data_lstm['Delayed_Time'][1] = data_lstm['Delayed_Time'][1] + dt.rin

rand_int = np.random.randint(1,10,size=34580) #random delay 
# static_int = 30 #to calculate static delay
# rand_int = np.random.uniform(1,10,size=34580) #uniform delay
data_xg['rand_int'] = rand_int
#pjme['static_int'] = static_int
data_xg.head(5)

# %%
#data_xg['Delayed_Time'] = data_xg.Delayed_Time + data_xg.rand_int.astype('timedelta64[h]') #to convert delay to hours
#data_xg['Delayed_Time'] = data_xg.Delayed_Time + data_xg.rand_int.astype('timedelta64[m]') #to convert delay to minutes
data_xg['Delayed_Time'] = data_xg.Delayed_Time + data_xg.rand_int.astype('timedelta64[s]') #to convert delay to seconds
data_xg.head(5)

# %%
data_xg.set_index('Delayed_Time')

# %%
data_xg_delayed = data_xg.set_index('Delayed_Time')
data_xg_delayed.head()

# %%
data_xg_delayed = data_xg_delayed.drop(['rand_int'],axis=1)
data_xg_delayed.head()

# %%
#Splitting the delayed datset
# split data
split_date = '25-06-2018'
# from datetime import datetime
# split_date_obj = datetime. strptime(split_date, "%d-%m-%Y %H:%M:%S")
data_train_delayed = data_xg_delayed.loc[data_xg_delayed.index <= split_date].copy()
data_test_delayed = data_xg_delayed.loc[data_xg_delayed.index > split_date].copy()

# %%
X_train, y_train = create_features(data_train_delayed, label='Weighted_Price')
X_test, y_test = create_features(data_test_delayed, label='Weighted_Price')

# %%
model =  xgb.XGBRegressor(objective ='reg:linear',min_child_weight=10, booster='gbtree', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 1000)
model.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False) # Change verbose to True if you want to see it train

# %%
data_test_delayed['Weighted_Price_Prediction'] = model.predict(X_test)
data_all_xg_delayed = pd.concat([data_test_delayed, data_train_delayed], sort=False)

# %%
# #adding to final data for comparision
# final_data_xg_delayed = pd.merge(final_data_xg_delayed, data_all_xg_delayed, sort=False)
# final_data_xg_delayed = final_data_xg_delayed.rename(columns={'Weighted_Price_Prediction': 'xgboost'})
# final_data_xg_delayed = final_data_xg_delayed[['Timestamp','Weighted_Price','lstm','xgboost']]

# %%
mean_squared_error(y_true=data_test_delayed['Weighted_Price'],
                   y_pred=data_test_delayed['Weighted_Price_Prediction'])

# %%
mean_absolute_error(y_true=data_test_delayed['Weighted_Price'],
                   y_pred=data_test_delayed['Weighted_Price_Prediction'])
